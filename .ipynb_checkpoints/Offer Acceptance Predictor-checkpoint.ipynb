# %% [markdown]
# # Offer acceptance predictor model
# ### Or, _"My First Neural Network"_
# In this notebook, we will:
# * Generate some random job offer data for graduate jobs
# * Create a toy model that gives the probability a candidate might accept an offer given the input data
# * Randomly accept/reject offers based on that probability
# * Build and train a neural network that can predict whether a candidate accepts or rejects (i.e. to try and replicate the toy model)
# * Use the model to tweak a company's offer to increase the chance the candidate will accept

# %%
# Import modules
import tensorflow as tf
#from tensorflow import keras
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate data:
# In the absence of a real dataset, make some assumptions about what real life data looks like. Inputs will be:
# * The salary included in the offer
# * The days of annual leave included in the offer
# * The number of employees in the company
# * The turnover of the company
# * The company's remote working policy (e.g. fully office/remote or hybrid)
# Make sure days leave and number of employees are generated as integers - no fractions of a day of leave or half employees!

# %%
# Randomly generate some data
n = int(1e6)

# Assume offers are normally distributed about £30k with a width of £1k
# Assert no offers are less than £15k or more than £50k
lower, upper = 1.5e4, 5e4
mu, sigma = 3.0e4, 1e4
offer = stats.truncnorm((lower - mu) / sigma,
                        (upper - mu) / sigma,
                        loc=mu, scale=sigma).rvs(n)
# Assume holidays are normally distributed about 25 days, with a width of 2 days, ignoring bank holidays
# Assert no offers include less than the statutory leave allownace or more than 30 days EXCEPT FOR
# offers of 31 days are actually from companies with infinite holiday policies
lower, upper = 20, 32
mu, sigma = 25, 2
holiday = stats.truncnorm((lower - mu) / sigma,
                          (upper - mu) / sigma,
                          loc=mu, scale=sigma).rvs(n).astype(int)
holiday = holiday.astype(float)
holiday[holiday == 31] = np.inf     # where 

# Assume the logarithm of the number of employees in a company is normally distributed about 2.5 with a width of 1
# Assert there are no companies with less than 1 employee or more than 100,000
lower, upper = 0, 5,
mu, sigma = 2.5, 1
employees = (10**stats.truncnorm((lower - mu) / sigma,
                                 (upper - mu) / sigma,
                                 loc=mu, scale=sigma).rvs(n)).astype(int)

# Assume a quarter of the offers include hybrid working
p = 1/4
hybrid = np.random.choice(a=[True, False], size=(n), p=[p, 1-p])

# Assume a quarter of those offers including hybrid working allow fully remote working
p = 1/4
remote = np.random.choice(a=[True, False], size=(n), p=[p, 1-p]) & hybrid

# Assume turnover is related to the square root of the number of employees, give or take
turnover = 1e4 * employees**0.5 * 10**np.random.normal(1, 0.2, n)


# Create a pandas dataframe for the data
df = pd.DataFrame({"Offer": offer,
                   "Holiday": holiday,
                   "Employees": employees,
                   "Turnover": turnover,
                   "Hybrid": hybrid,
                   "Remote": remote})

df.head()
# Out:
#           Offer  Holiday  Employees      Turnover  Hybrid  Remote
# 0  16087.584489     24.0        503  1.455022e+06   False   False
# 1  23888.218458     24.0        539  1.876849e+06    True   False
# 2  35607.452731     26.0          7  9.892556e+04   False   False
# 3  46269.812565     23.0        112  1.399166e+06    True   False
# 4  24439.721871     25.0        656  2.860967e+06   False   False

# %% [markdown]
# # Create a toy model
# Create functions that normalise the data between 0 and 1 so that probabilities can be generated by weighting the inputs.
# Assume:
# * the probability of offer acceptance is related to the order of magnitude of the offer (significance of the difference between £15k and £17k is larger than the significance of the difference between £48k and £50k)
# * the significance of the number of holidays exponentially decays, such that statutory holidays returns 0 and infinite holidays returns 1
# * candidates like to work for small start-up companies because they're exciting, but candidates also like to work for large companies because they are stable and have "big names" (e.g. Microsoft, Google)
# * the probability of the offer acceptance is related to the order of magnitude of turnover
#
# Create a function to combine all the normalised inputs based on weights. Assume beyond a certain point, offers are too good to refuse - therefore don't divide by the sum of the weights. Make sure no probabilities are greater than 1.

# %%
# Normalise data
def normalise(input_data, reference_data=None):
    if reference_data is None: reference_data = input_data
    return (input_data - np.min(reference_data))/np.ptp(reference_data)

# Function for probability of acceptance
def acceptance_probability(variables, weights, factor=1):
    p = (variables.T * weights).sum(axis=1) * factor
    p[p>1] = 1
    return p

def toy_model(input_dataframe, toy_model_weights=None, factor=1):
    # If no weights input, assume all weights are equal
    if toy_model_weights is None: toy_model_weights = np.ones(len(input_dataframe.columns))/len(input_dataframe.columns)
        
    # Normalise the input data between  0 and 1
    offer_n = normalise(np.log(input_dataframe['Offer']))
    holiday_n = 1 - np.exp(1 - input_dataframe['Holiday']/20)
    employees_n = normalise(1/(1+np.log(input_dataframe['Employees'])) + np.log(input_dataframe['Employees'])/10)
    turnover_n = normalise(np.log(input_dataframe['Turnover']))
    hybrid_n = input_dataframe['Hybrid'].astype(int)
    remote_n = input_dataframe['Remote'].astype(int)
    
    # Create an array for the variables
    variables = np.array([offer_n, holiday_n, employees_n, turnover_n, hybrid_n, remote_n])
    
    # Calculate the probability of acceptance
    acceptance = acceptance_probability(variables, weights, factor)
    
    return acceptance

# Create some weights for the toy model
#                             Offer    Holiday    Employees    Turnover    Hybrid    Remote
weights = normalise(np.array([9,       6,         4,           2,          3,        4])) / len(df.columns)

acceptance = toy_model(input_dataframe = df,
                       toy_model_weights = weights,
                       factor = 5)

# %% [markdown]
# Demonstrate the spread of the toy model by plotting the probability of acceptance against the offer. Note the probability is capped at 1.

# %%
fig = plt.figure()
ax = fig.add_subplot()
hb = ax.hexbin(offer/1e3, acceptance, gridsize=128, mincnt=1, bins='log')
ax.set_xlabel('Offer (£1000s)')
ax.set_ylabel('Probability of acceptance')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Counts')

# %% [markdown]
# Randomly accept or reject offers based on their probability.

# %%
# Decide if accepted or rejected
accepted = np.where(np.random.uniform(size=n) < acceptance, True, False)
print('Fraction of all offers accepted: {0:.2f}'.format(accepted.mean()))
# Out:
# Fraction of all offers accepted: 0.68

# %% [markdown]
# # Build and train a neural network to replicate the toy model

# %%
# Create a function to extract features from the dataset
# Although we already know the important features from the model, let's pretend we don't
def get_features(input_dataframe, reference_dataframe=None):
    # If there is no reference data against which to normalise, use the input data
    if reference_dataframe is None: reference_dataframe = input_dataframe
    
    offer = normalise(input_dataframe['Offer'], reference_dataframe['Offer'])
    offer2 = offer**2
    offersqrt = offer**0.5
    offerlog = normalise(np.log(input_dataframe['Offer']), np.log(reference_dataframe['Offer']))
    
    holiday = normalise(input_dataframe['Holiday'], reference_dataframe['Holiday'].replace(np.inf, np.nan))
    holiday2 = holiday**2
    holidaysqrt = holiday**0.5
    holidaytanh = np.tanh(input_dataframe['Holiday']/20 - 1)
    holidayexpdec = 1 - np.exp(1 - input_dataframe['Holiday']/20)
    
    employees = normalise(input_dataframe['Employees'], reference_dataframe['Employees'])
    employees2 = employees**2
    employeessqrt = employees**0.5
    employeesinv = employees**-1
    employees2inv = employees**-2
    employeessqrtinv = employees**-0.5
    employeeslog = normalise(np.log(input_dataframe['Employees']), np.log(reference_dataframe['Employees']))
    
    turnover = normalise(input_dataframe['Turnover'], reference_dataframe['Turnover'])
    turnover2 = turnover**2
    turnoversqrt = turnover**0.5
    turnoverlog = normalise(np.log(input_dataframe['Turnover']), np.log(reference_dataframe['Turnover']))

    hybrid_n = input_dataframe['Hybrid'].astype(int)
    remote_n = input_dataframe['Remote'].astype(int)

    # THIS NOT WORKING YET
    #    return np.array([offer, offer2, offersqrt, offerlog,
    #                     holiday, holiday2, holidaysqrt, holidaytanh,
    #                     employees, employees2, employeessqrt, employeesinv, employees2inv, employeessqrtinv, employeeslog,
    #                     turnover, turnover2, turnoversqrt, turnoverlog,
    #                     hybrid_n,
    #                     remote_n])

    # CHEAT AND USE FEATURES FROM TOY MODEL
    return np.array([offerlog,
                     holidayexpdec,
                     employeeslog, 1/(1+employeeslog),
                     turnoverlog,
                     hybrid_n,
                     remote_n])

# %%
#from tensorflow.keras import datasets, layers, models

X = get_features(df).T
y = accepted.astype(int)

# Build
model = tf.keras.Sequential([tf.keras.layers.Dense(64, input_shape=(X.shape[1],), activation='relu'),
                             tf.keras.layers.Dense(16, activation='relu'),
                             tf.keras.layers.Dense(4, activation='relu'),
                             tf.keras.layers.Dense(1, activation='sigmoid'), # The last layer must output a 0 or 1, hence sigmoid activation
                             ])

# Compile
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

#train
history = model.fit(X, y, verbose = 1,
                    validation_split = 0.5,
                    epochs=10, 
                    batch_size = 1024)
# Out:
# Epoch 1/10
# 489/489 [==============================] - 5s 9ms/step - loss: 0.5413 - accuracy: 0.7184 - val_loss: 0.5241 - val_accuracy: 0.7312
# Epoch 2/10
# 489/489 [==============================] - 4s 8ms/step - loss: 0.5226 - accuracy: 0.7319 - val_loss: 0.5202 - val_accuracy: 0.7317
# Epoch 3/10
# 489/489 [==============================] - 4s 8ms/step - loss: 0.5194 - accuracy: 0.7322 - val_loss: 0.5185 - val_accuracy: 0.7315
# Epoch 4/10
# 489/489 [==============================] - 4s 9ms/step - loss: 0.5180 - accuracy: 0.7321 - val_loss: 0.5197 - val_accuracy: 0.7315
# Epoch 5/10
# 489/489 [==============================] - 4s 8ms/step - loss: 0.5172 - accuracy: 0.7320 - val_loss: 0.5166 - val_accuracy: 0.7318
# Epoch 6/10
# 489/489 [==============================] - 4s 8ms/step - loss: 0.5165 - accuracy: 0.7325 - val_loss: 0.5172 - val_accuracy: 0.7317
# Epoch 7/10
# ...

# %% [markdown]
# Plot the accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy','validation accuracy'])

# %% [markdown]
# # Use the model to optimise a company's offer.
# **First, show how the number of employees and remote working policy affects the probability of acceptance of an offer of £25k and statutory leave allowances. Assume turnover is the average turnover for the given company size.**

# %%
i = 101

# Create some data and normalise in the same way as the inputs to the model
o = np.array([25000]*i)
h = np.array([20]*i)
e = np.logspace(0,5,i)
t = 1e4 * e**0.5

data_office = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.zeros(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_hybrid = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_remote = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.ones(i).astype(bool)})

# Use the model to predict the acceptance based on the inputs
office = model.predict(get_features(data_office, df).T)
hybrid = model.predict(get_features(data_hybrid, df).T)
remote = model.predict(get_features(data_remote, df).T)

# Plot the results
fig = plt.figure()
ax = fig.add_subplot()
ax.semilogx(e, office, label='Office')
ax.semilogx(e, hybrid, label='Hybrid')
ax.semilogx(e, remote, label='Remote')
ax.set_ylim([0, 1.05])
ax.set_yticks(np.linspace(0, 1, 11))
ax.set_xlabel('Employees')
ax.set_ylabel('Probability offer accepted')
ax.grid()
ax.legend()

# %% [markdown]
# **Show how a company with a given number of employees can change the probability by changing the offer amount.**

# %%
i = 101

o = np.linspace(15000,45000,i)
h = np.array([20]*i)
e = np.array([1000]*i)
t = 1e4 * e**0.5

data_office = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.zeros(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_hybrid = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_remote = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.ones(i).astype(bool)})

# Use the model to predict the acceptance based on the inputs
office = model.predict(get_features(data_office, df).T)
hybrid = model.predict(get_features(data_hybrid, df).T)
remote = model.predict(get_features(data_remote, df).T)

# Plot the results
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(o/1e3, office, label='Office')
ax.plot(o/1e3, hybrid, label='Hybrid')
ax.plot(o/1e3, remote, label='Remote')
ax.set_ylim([0, 1.05])
ax.set_yticks(np.linspace(0, 1, 11))
ax.set_xlabel('Offer (£1000s)')
ax.set_ylabel('Probability offer accepted')
ax.grid()
ax.legend()

# %% [markdown]
# **Choose a new offer, and show how probability varies with the number of days leave offered.**

# %%
i = 12
o = np.array([35000]*i)
h = np.linspace(20,31,i)
h[h == 31] = np.inf
e = np.array([1000]*i)
t = 1e4 * e**0.5

data_office = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.zeros(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_hybrid = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.zeros(i).astype(bool)})

data_remote = pd.DataFrame({"Offer": o,
                            "Holiday": h,
                            "Employees": e,
                            "Turnover": t,
                            "Hybrid": np.ones(i).astype(bool),
                            "Remote": np.ones(i).astype(bool)})

# Use the model to predict the acceptance based on the inputs
office = model.predict(get_features(data_office, df).T)
hybrid = model.predict(get_features(data_hybrid, df).T)
remote = model.predict(get_features(data_remote, df).T)

# Plot the results
fig = plt.figure()
ax = fig.add_subplot()
H = np.linspace(20,31,i)
ax.plot(H, office, label='Office')
ax.plot(H, hybrid, label='Hybrid')
ax.plot(H, remote, label='Remote')
ax.set_ylim([0, 1.05])
ax.set_yticks(np.linspace(0, 1, 11))
ax.set_xticks(H)
xticklabels = H.astype(int).astype(str)
xticklabels[-1] = "Infinite"
ax.set_xticklabels(xticklabels)
ax.set_xlabel('Leave allowance (days)')
ax.set_ylabel('Probability offer accepted')
ax.grid()
ax.legend()

# %% [markdown]
# **Check the accuracy of the model against all data**

# %%
_, accuracy = model.evaluate(X, accepted)
print(f'The model accuracy is {accuracy * 100:0.1f}%')
# Out:
# 31250/31250 [==============================] - 90s 3ms/step - loss: 0.5156 - accuracy: 0.7321
# The model accuracy is 73.2%
